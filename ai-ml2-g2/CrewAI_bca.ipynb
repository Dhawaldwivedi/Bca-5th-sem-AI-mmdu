# %% [markdown]
# <a href="https://colab.research.google.com/github/Dhawaldwivedi/Bca-5th-sem-AI-mmdu/blob/main/ai-ml2-g2/CrewAI_bca.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install crewai crewai-tools langchain-google-genai
# Out:
# Requirement already satisfied: crewai in /usr/local/lib/python3.12/dist-packages (1.3.0)
# Requirement already satisfied: crewai-tools in /usr/local/lib/python3.12/dist-packages (1.3.0)
# Requirement already satisfied: langchain-google-genai in /usr/local/lib/python3.12/dist-packages (3.0.1)
# Requirement already satisfied: appdirs>=1.4.4 in /usr/local/lib/python3.12/dist-packages (from crewai) (1.4.4)
# Requirement already satisfied: chromadb~=1.1.0 in /usr/local/lib/python3.12/dist-packages (from crewai) (1.1.1)
# Requirement already satisfied: click>=8.1.7 in /usr/local/lib/python3.12/dist-packages (from crewai) (8.3.0)
# Requirement already satisfied: instructor>=1.3.3 in /usr/local/lib/python3.12/dist-packages (from crewai) (1.13.0)
# Requirement already satisfied: json-repair==0.25.2 in /usr/local/lib/python3.12/dist-packages (from crewai) (0.25.2)
# Requirement already satisfied: json5>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from crewai) (0.12.1)
# Requirement already satisfied: jsonref>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from crewai) (1.1.0)
# Requirement already satisfied: mcp>=1.16.0 in /usr/local/lib/python3.12/dist-packages (from crewai) (1.20.0)
# Requirement already satisfied: openai>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from crewai) (2.7.1)
# Requirement already satisfied: openpyxl>=3.1.5 in /usr/local/lib/python3.12/dist-packages (from crewai) (3.1.5)
# Requirement already satisfied: opentelemetry-api>=1.30.0 in /usr/local/lib/python3.12/dist-packages (from crewai) (1.37.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http>=1.30.0 in /usr/local/lib/python3.12/dist-packages (from crewai) (1.37.0)
# Requirement already satisfied: opentelemetry-sdk>=1.30.0 in /usr/local/lib/python3.12/dist-packages (from crewai) (1.37.0)
# Requirement already satisfied: pdfplumber>=0.11.4 in /usr/local/lib/python3.12/dist-packages (from crewai) (0.11.7)
# Requirement already satisfied: portalocker==2.7.0 in /usr/local/lib/python3.12/dist-packages (from crewai) (2.7.0)
# Requirement already satisfied: pydantic-settings>=2.10.1 in /usr/local/lib/python3.12/dist-packages (from crewai) (2.11.0)
# Requirement already satisfied: pydantic>=2.11.9 in /usr/local/lib/python3.12/dist-packages (from crewai) (2.11.10)
# Requirement already satisfied: pyjwt>=2.9.0 in /usr/local/lib/python3.12/dist-packages (from crewai) (2.10.1)
# Requirement already satisfied: python-dotenv>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from crewai) (1.2.1)
# Requirement already satisfied: regex>=2024.9.11 in /usr/local/lib/python3.12/dist-packages (from crewai) (2024.11.6)
# Requirement already satisfied: tokenizers>=0.20.3 in /usr/local/lib/python3.12/dist-packages (from crewai) (0.22.1)
# Requirement already satisfied: tomli-w>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from crewai) (1.2.0)
# Requirement already satisfied: tomli>=2.0.2 in /usr/local/lib/python3.12/dist-packages (from crewai) (2.3.0)
# Requirement already satisfied: uv>=0.4.25 in /usr/local/lib/python3.12/dist-packages (from crewai) (0.9.7)
# Requirement already satisfied: beautifulsoup4>=4.13.4 in /usr/local/lib/python3.12/dist-packages (from crewai-tools) (4.13.5)
# Requirement already satisfied: docker>=7.1.0 in /usr/local/lib/python3.12/dist-packages (from crewai-tools) (7.1.0)
# Requirement already satisfied: lancedb>=0.5.4 in /usr/local/lib/python3.12/dist-packages (from crewai-tools) (0.25.2)
# Requirement already satisfied: pypdf>=5.9.0 in /usr/local/lib/python3.12/dist-packages (from crewai-tools) (6.1.3)
# Requirement already satisfied: python-docx>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from crewai-tools) (1.2.0)
# Requirement already satisfied: pytube>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from crewai-tools) (15.0.0)
# Requirement already satisfied: requests>=2.32.5 in /usr/local/lib/python3.12/dist-packages (from crewai-tools) (2.32.5)
# Requirement already satisfied: tiktoken>=0.8.0 in /usr/local/lib/python3.12/dist-packages (from crewai-tools) (0.12.0)
# Requirement already satisfied: youtube-transcript-api>=1.2.2 in /usr/local/lib/python3.12/dist-packages (from crewai-tools) (1.2.3)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langchain-google-genai) (1.0.3)
# Requirement already satisfied: google-ai-generativelanguage<1.0.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from langchain-google-genai) (0.9.0)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from langchain-google-genai) (1.2.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4>=4.13.4->crewai-tools) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4>=4.13.4->crewai-tools) (4.15.0)
# Requirement already satisfied: build>=1.0.3 in /usr/local/lib/python3.12/dist-packages (from chromadb~=1.1.0->crewai) (1.3.0)
# Requirement already satisfied: pybase64>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from chromadb~=1.1.0->crewai) (1.4.2)
# Requirement already satisfied: uvicorn>=0.18.3 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.18.3->chromadb~=1.1.0->crewai) (0.38.0)
# Requirement already satisfied: numpy>=1.22.5 in /usr/local/lib/python3.12/dist-packages (from chromadb~=1.1.0->crewai) (2.0.2)
# Requirement already satisfied: posthog<6.0.0,>=2.4.0 in /usr/local/lib/python3.12/dist-packages (from chromadb~=1.1.0->crewai) (5.4.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in /usr/local/lib/python3.12/dist-packages (from chromadb~=1.1.0->crewai) (1.23.2)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from chromadb~=1.1.0->crewai) (1.37.0)
# Requirement already satisfied: pypika>=0.48.9 in /usr/local/lib/python3.12/dist-packages (from chromadb~=1.1.0->crewai) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in /usr/local/lib/python3.12/dist-packages (from chromadb~=1.1.0->crewai) (4.67.1)
# Requirement already satisfied: overrides>=7.3.1 in /usr/local/lib/python3.12/dist-packages (from chromadb~=1.1.0->crewai) (7.7.0)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.12/dist-packages (from chromadb~=1.1.0->crewai) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in /usr/local/lib/python3.12/dist-packages (from chromadb~=1.1.0->crewai) (1.76.0)
# Requirement already satisfied: bcrypt>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from chromadb~=1.1.0->crewai) (5.0.0)
# Requirement already satisfied: typer>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from chromadb~=1.1.0->crewai) (0.20.0)
# Requirement already satisfied: kubernetes>=28.1.0 in /usr/local/lib/python3.12/dist-packages (from chromadb~=1.1.0->crewai) (34.1.0)
# Requirement already satisfied: tenacity>=8.2.3 in /usr/local/lib/python3.12/dist-packages (from chromadb~=1.1.0->crewai) (8.5.0)
# Requirement already satisfied: pyyaml>=6.0.0 in /usr/local/lib/python3.12/dist-packages (from chromadb~=1.1.0->crewai) (6.0.3)
# Requirement already satisfied: mmh3>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from chromadb~=1.1.0->crewai) (5.2.0)
# Requirement already satisfied: orjson>=3.9.12 in /usr/local/lib/python3.12/dist-packages (from chromadb~=1.1.0->crewai) (3.11.4)
# Requirement already satisfied: httpx>=0.27.0 in /usr/local/lib/python3.12/dist-packages (from chromadb~=1.1.0->crewai) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.12/dist-packages (from chromadb~=1.1.0->crewai) (13.9.4)
# Requirement already satisfied: jsonschema>=4.19.0 in /usr/local/lib/python3.12/dist-packages (from chromadb~=1.1.0->crewai) (4.25.1)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from docker>=7.1.0->crewai-tools) (2.3.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1 in /usr/local/lib/python3.12/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<1.0.0,>=0.7.0->langchain-google-genai) (2.28.1)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1 in /usr/local/lib/python3.12/dist-packages (from google-ai-generativelanguage<1.0.0,>=0.7.0->langchain-google-genai) (2.38.0)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /usr/local/lib/python3.12/dist-packages (from google-ai-generativelanguage<1.0.0,>=0.7.0->langchain-google-genai) (1.26.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2 in /usr/local/lib/python3.12/dist-packages (from google-ai-generativelanguage<1.0.0,>=0.7.0->langchain-google-genai) (5.29.5)
# Requirement already satisfied: aiohttp<4.0.0,>=3.9.1 in /usr/local/lib/python3.12/dist-packages (from instructor>=1.3.3->crewai) (3.13.2)
# Requirement already satisfied: diskcache>=5.6.3 in /usr/local/lib/python3.12/dist-packages (from instructor>=1.3.3->crewai) (5.6.3)
# Requirement already satisfied: docstring-parser<1.0,>=0.16 in /usr/local/lib/python3.12/dist-packages (from instructor>=1.3.3->crewai) (0.17.0)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from instructor>=1.3.3->crewai) (3.1.6)
# Requirement already satisfied: jiter<0.12,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from instructor>=1.3.3->crewai) (0.11.1)
# Requirement already satisfied: pre-commit>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from instructor>=1.3.3->crewai) (4.3.0)
# Requirement already satisfied: pydantic-core<3.0.0,>=2.18.0 in /usr/local/lib/python3.12/dist-packages (from instructor>=1.3.3->crewai) (2.33.2)
# Requirement already satisfied: ty>=0.0.1a23 in /usr/local/lib/python3.12/dist-packages (from instructor>=1.3.3->crewai) (0.0.1a25)
# Requirement already satisfied: deprecation in /usr/local/lib/python3.12/dist-packages (from lancedb>=0.5.4->crewai-tools) (2.1.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from lancedb>=0.5.4->crewai-tools) (25.0)
# Requirement already satisfied: pyarrow>=16 in /usr/local/lib/python3.12/dist-packages (from lancedb>=0.5.4->crewai-tools) (18.1.0)
# Requirement already satisfied: lance-namespace>=0.0.16 in /usr/local/lib/python3.12/dist-packages (from lancedb>=0.5.4->crewai-tools) (0.0.20)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.0.0->langchain-google-genai) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.0.0->langchain-google-genai) (0.4.40)
# Requirement already satisfied: anyio>=4.5 in /usr/local/lib/python3.12/dist-packages (from mcp>=1.16.0->crewai) (4.11.0)
# Requirement already satisfied: httpx-sse>=0.4 in /usr/local/lib/python3.12/dist-packages (from mcp>=1.16.0->crewai) (0.4.3)
# Requirement already satisfied: python-multipart>=0.0.9 in /usr/local/lib/python3.12/dist-packages (from mcp>=1.16.0->crewai) (0.0.20)
# Requirement already satisfied: sse-starlette>=1.6.1 in /usr/local/lib/python3.12/dist-packages (from mcp>=1.16.0->crewai) (3.0.3)
# Requirement already satisfied: starlette>=0.27 in /usr/local/lib/python3.12/dist-packages (from mcp>=1.16.0->crewai) (0.49.3)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai>=1.13.3->crewai) (1.9.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai>=1.13.3->crewai) (1.3.1)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.12/dist-packages (from openpyxl>=3.1.5->crewai) (2.0.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-api>=1.30.0->crewai) (8.7.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp-proto-http>=1.30.0->crewai) (1.71.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.37.0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp-proto-http>=1.30.0->crewai) (1.37.0)
# Requirement already satisfied: opentelemetry-proto==1.37.0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp-proto-http>=1.30.0->crewai) (1.37.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.58b0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-sdk>=1.30.0->crewai) (0.58b0)
# Requirement already satisfied: pdfminer.six==20250506 in /usr/local/lib/python3.12/dist-packages (from pdfplumber>=0.11.4->crewai) (20250506)
# Requirement already satisfied: Pillow>=9.1 in /usr/local/lib/python3.12/dist-packages (from pdfplumber>=0.11.4->crewai) (11.3.0)
# Requirement already satisfied: pypdfium2>=4.18.0 in /usr/local/lib/python3.12/dist-packages (from pdfplumber>=0.11.4->crewai) (5.0.0)
# Requirement already satisfied: charset-normalizer>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from pdfminer.six==20250506->pdfplumber>=0.11.4->crewai) (3.4.4)
# Requirement already satisfied: cryptography>=36.0.0 in /usr/local/lib/python3.12/dist-packages (from pdfminer.six==20250506->pdfplumber>=0.11.4->crewai) (43.0.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.11.9->crewai) (0.7.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.11.9->crewai) (0.4.2)
# Requirement already satisfied: lxml>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from python-docx>=1.2.0->crewai-tools) (5.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.5->crewai-tools) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.5->crewai-tools) (2025.10.5)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in /usr/local/lib/python3.12/dist-packages (from tokenizers>=0.20.3->crewai) (0.36.0)
# Requirement already satisfied: defusedxml<0.8.0,>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from youtube-transcript-api>=1.2.2->crewai-tools) (0.7.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.9.1->instructor>=1.3.3->crewai) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.9.1->instructor>=1.3.3->crewai) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.9.1->instructor>=1.3.3->crewai) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.9.1->instructor>=1.3.3->crewai) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.9.1->instructor>=1.3.3->crewai) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.9.1->instructor>=1.3.3->crewai) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.9.1->instructor>=1.3.3->crewai) (1.22.0)
# Requirement already satisfied: pyproject_hooks in /usr/local/lib/python3.12/dist-packages (from build>=1.0.3->chromadb~=1.1.0->crewai) (1.2.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<1.0.0,>=0.7.0->langchain-google-genai) (1.71.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<1.0.0,>=0.7.0->langchain-google-genai) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<1.0.0,>=0.7.0->langchain-google-genai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<1.0.0,>=0.7.0->langchain-google-genai) (4.9.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx>=0.27.0->chromadb~=1.1.0->crewai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx>=0.27.0->chromadb~=1.1.0->crewai) (0.16.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.20.3->crewai) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.20.3->crewai) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.20.3->crewai) (1.2.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.30.0->crewai) (3.23.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2<4.0.0,>=3.1.4->instructor>=1.3.3->crewai) (3.0.3)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.0->langchain-google-genai) (3.0.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.19.0->chromadb~=1.1.0->crewai) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.19.0->chromadb~=1.1.0->crewai) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.19.0->chromadb~=1.1.0->crewai) (0.28.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from kubernetes>=28.1.0->chromadb~=1.1.0->crewai) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.12/dist-packages (from kubernetes>=28.1.0->chromadb~=1.1.0->crewai) (2.9.0.post0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /usr/local/lib/python3.12/dist-packages (from kubernetes>=28.1.0->chromadb~=1.1.0->crewai) (1.9.0)
# Requirement already satisfied: requests-oauthlib in /usr/local/lib/python3.12/dist-packages (from kubernetes>=28.1.0->chromadb~=1.1.0->crewai) (2.0.0)
# Requirement already satisfied: durationpy>=0.7 in /usr/local/lib/python3.12/dist-packages (from kubernetes>=28.1.0->chromadb~=1.1.0->crewai) (0.10)
# Requirement already satisfied: lance-namespace-urllib3-client in /usr/local/lib/python3.12/dist-packages (from lance-namespace>=0.0.16->lancedb>=0.5.4->crewai-tools) (0.0.20)
# Requirement already satisfied: pylance>=0.18.0 in /usr/local/lib/python3.12/dist-packages (from lance-namespace>=0.0.16->lancedb>=0.5.4->crewai-tools) (0.39.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-google-genai) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-google-genai) (0.25.0)
# Requirement already satisfied: coloredlogs in /usr/local/lib/python3.12/dist-packages (from onnxruntime>=1.14.1->chromadb~=1.1.0->crewai) (15.0.1)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.12/dist-packages (from onnxruntime>=1.14.1->chromadb~=1.1.0->crewai) (25.9.23)
# Requirement already satisfied: sympy in /usr/local/lib/python3.12/dist-packages (from onnxruntime>=1.14.1->chromadb~=1.1.0->crewai) (1.13.3)
# Requirement already satisfied: backoff>=1.10.0 in /usr/local/lib/python3.12/dist-packages (from posthog<6.0.0,>=2.4.0->chromadb~=1.1.0->crewai) (2.2.1)
# Requirement already satisfied: cfgv>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from pre-commit>=4.3.0->instructor>=1.3.3->crewai) (3.4.0)
# Requirement already satisfied: identify>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from pre-commit>=4.3.0->instructor>=1.3.3->crewai) (2.6.15)
# Requirement already satisfied: nodeenv>=0.11.1 in /usr/local/lib/python3.12/dist-packages (from pre-commit>=4.3.0->instructor>=1.3.3->crewai) (1.9.1)
# Requirement already satisfied: virtualenv>=20.10.0 in /usr/local/lib/python3.12/dist-packages (from pre-commit>=4.3.0->instructor>=1.3.3->crewai) (20.35.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->chromadb~=1.1.0->crewai) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->chromadb~=1.1.0->crewai) (2.19.2)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer>=0.9.0->chromadb~=1.1.0->crewai) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.18.3->chromadb~=1.1.0->crewai) (0.7.1)
# Requirement already satisfied: uvloop>=0.15.1 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.18.3->chromadb~=1.1.0->crewai) (0.22.1)
# Requirement already satisfied: watchfiles>=0.13 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.18.3->chromadb~=1.1.0->crewai) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.18.3->chromadb~=1.1.0->crewai) (15.0.1)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.12/dist-packages (from cryptography>=36.0.0->pdfminer.six==20250506->pdfplumber>=0.11.4->crewai) (2.0.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb~=1.1.0->crewai) (0.1.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<1.0.0,>=0.7.0->langchain-google-genai) (0.6.1)
# Requirement already satisfied: distlib<1,>=0.3.7 in /usr/local/lib/python3.12/dist-packages (from virtualenv>=20.10.0->pre-commit>=4.3.0->instructor>=1.3.3->crewai) (0.4.0)
# Requirement already satisfied: platformdirs<5,>=3.9.1 in /usr/local/lib/python3.12/dist-packages (from virtualenv>=20.10.0->pre-commit>=4.3.0->instructor>=1.3.3->crewai) (4.5.0)
# Requirement already satisfied: humanfriendly>=9.1 in /usr/local/lib/python3.12/dist-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb~=1.1.0->crewai) (10.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb~=1.1.0->crewai) (3.3.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy->onnxruntime>=1.14.1->chromadb~=1.1.0->crewai) (1.3.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six==20250506->pdfplumber>=0.11.4->crewai) (2.23)

# %%
import os
from crewai import Agent, Task, Crew, Process, LLM
from crewai_tools import SerperDevTool
from google.colab import userdata

# %% [markdown]
# # Gemini API

# %%
gemini_llm = LLM(
    model="gemini/gemini-2.5-flash",
    api_key=userdata.get('GOOGLE_API_KEY')
)

# %% [markdown]
# # Serper API

# %% [markdown]
# https://www.google.com/url?q=https%3A%2F%2Fserper.dev%2Fapi-keys

# %%
# Load the API key from Colab secrets
serper_api_key = userdata.get('SERPER_API_KEY')

# Set it as an environment variable
os.environ["SERPER_API_KEY"] = serper_api_key

search_tool = SerperDevTool()

# %% [markdown]
# # Creating Researcher Agent

# %%
researcher = Agent(
  role='Market Researcher',
  goal='Find and analyze the latest trends in the AI industry',
  backstory="""You are an expert market researcher. You are skilled at
  finding the most relevant and up-to-date information on any given
  topic, and you are known for your ability to synthesize complex
  information into clear and concise summaries.""",
  verbose=True,
  allow_delegation=False,
  tools=[search_tool],
  llm=gemini_llm
)

# %% [markdown]
# # Creating writer agent

# %%
writer = Agent(
  role='Content Writer',
  goal='Write a compelling and engaging blog post about the latest AI trends',
  backstory="""You are a renowned content writer, known for your ability
  to create engaging and informative content. You have a knack for
  turning complex topics into easy-to-understand articles that
  resonate with a wide audience.""",
  verbose=True,
  allow_delegation=True,
  llm=gemini_llm
)

# %% [markdown]
# # Defining Researcher Task

# %%
research_task = Task(
  description="""Research the latest trends in the AI industry.
  Your research should focus on the most significant advancements,
  emerging technologies, and key players. The final output should be a
  detailed report with your findings.""",
  expected_output='A comprehensive report summarizing the latest AI trends.',
  agent=researcher
)

# %% [markdown]
# # Defining Writer Task

# %%
write_task = Task(
  description="""Write a blog post based on the research findings.
  The blog post should be engaging, informative, and accessible to a
  non-technical audience. It should highlight the key trends and their
  potential impact on the future.""",
  expected_output='A 500-word blog post on the latest AI trends.',
  agent=writer
)

# %% [markdown]
# # Creating the crew

# %%
marketing_crew = Crew(
  agents=[researcher, writer],
  tasks=[research_task, write_task],
  process=Process.sequential,
  verbose=True
)

# %%
result = marketing_crew.kickoff()
# Out:
# ╭──────────────────────────────────────────── Crew Execution Started ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: f5c84a4d-46c1-4e40-92e5-172cbe9b3fb7                                                                       │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Market Researcher                                                                                       │
# │                                                                                                                 │
# │  Task: Research the latest trends in the AI industry.                                                           │
# │    Your research should focus on the most significant advancements,                                             │
# │    emerging technologies, and key players. The final output should be a                                         │
# │    detailed report with your findings.                                                                          │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────── 🔧 Agent Tool Execution ────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Market Researcher                                                                                       │
# │                                                                                                                 │
# │  Thought: Action: Search the internet with Serper                                                               │
# │                                                                                                                 │
# │  Using Tool: Search the internet with Serper                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Input ───────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  {                                                                                                              │
# │    "search_query": "latest AI trends 2024"                                                                      │
# │  }                                                                                                              │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Output ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  {'searchParameters': {'q': 'latest AI trends 2024', 'type': 'search', 'num': 10, 'engine': 'google'},          │
# │  'organic': [{'title': 'The Top Artificial Intelligence Trends | IBM', 'link':                                  │
# │  'https://www.ibm.com/think/insights/artificial-intelligence-trends', 'snippet': 'The latest AI trends,         │
# │  brought to you by experts. Get curated insights on the most important—and intriguing—AI news. Subscribe to     │
# │  our weekly Think newsletter ...', 'position': 1}, {'title': 'Data and AI Trends 2024', 'link':                 │
# │  'https://data-ai-trends.withgoogle.com/', 'snippet': 'Data and AI Trends 2024. Data is the fuel for AI, and    │
# │  what powers its effectiveness. To truly take advantage of generative AI, you need to ground AI in your ent     │
# │  ...', 'position': 2}, {'title': 'McKinsey technology trends outlook 2025', 'link':                             │
# │  'https://www.mckinsey.com/capabilities/tech-and-ai/our-insights/the-top-trends-in-tech', 'snippet': 'An        │
# │  overarching artificial intelligence category replaces these four trends: applied AI, generative AI,            │
# │  industrializing machine learning, and ...', 'position': 3, 'sitelinks': [{'title': 'Research Methodology',     │
# │  'link':                                                                                                        │
# │  'https://www.mckinsey.com/capabilities/tech-and-ai/our-insights/the-top-trends-in-tech#:~:text=Research%20met  │
# │  hodology,-To%20assess%20the%20development%20of'}, {'title': 'New And Notable', 'link':                         │
# │  'https://www.mckinsey.com/capabilities/tech-and-ai/our-insights/the-top-trends-in-tech#:~:text=New%20and%20no  │
# │  table,-In%20addition%20to%20the%20growing'}, {'title': 'The 13 Tech Trends', 'link':                           │
# │  'https://www.mckinsey.com/capabilities/tech-and-ai/our-insights/the-top-trends-in-tech#:~:text=The%2013%20tec  │
# │  h%20trends,-This%20report%20lays%20out%20considerations'}]}, {'title': 'The 2025 AI Index Report | Stanford    │
# │  HAI', 'link': 'https://hai.stanford.edu/ai-index/2025-ai-index-report', 'snippet': '10. Industry is racing     │
# │  ahead in AI—but the frontier is tightening. Nearly 90% of notable AI models in 2024 came from industry, up     │
# │  from 60% in 2023, while ...', 'position': 4, 'sitelinks': [{'title': '2024...                                  │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────── 🔧 Agent Tool Execution ────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Market Researcher                                                                                       │
# │                                                                                                                 │
# │  Thought: Thought: The initial search for "latest AI trends 2024" has yielded several promising results from    │
# │  reputable sources like IBM, Google, McKinsey, Stanford HAI, and Coursera. These snippets highlight key areas   │
# │  such as Generative AI, Multimodal AI, AI in the workplace, ethical AI, sustainability, and industry adoption.  │
# │  To provide a comprehensive report, I need to delve deeper into these specific trends, identifying the          │
# │  significant advancements, emerging technologies, and key players associated with each.                         │
# │  I will start by extracting information from some of the most relevant links to cover a broader range of        │
# │  topics. I will prioritize links from well-known industry leaders and research institutions.                    │
# │                                                                                                                 │
# │  Using Tool: Search the internet with Serper                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────── 🔧 Agent Tool Execution ────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Market Researcher                                                                                       │
# │                                                                                                                 │
# │  Thought: Thought: The previous search on "Generative AI advancements and key players 2024" provided a good     │
# │  overview of the significant momentum in this area. I now have information on:                                  │
# │  *   **Investment:** Generative AI attracted $33.9 billion globally in private investment in 2024, an 18.7%     │
# │  increase from 2023 (Stanford HAI).                                                                             │
# │  *   **Key Players/Companies:** OpenAI, Google DeepMind, IBM Watson, Microsoft Azure AI, NVIDIA AI, Amazon Web  │
# │  Services, Adobe Sensei, Anthropic AI, SAP (partnering with Google, Meta, Microsoft, NVIDIA), Deloitte          │
# │  (delivered over 700 generative AI projects).                                                                   │
# │  *   **Advancements/Applications:** Updates to Google's Imagen, Veo, and MusicFX (text-to-image/video/audio),   │
# │  AI-generated art and drug discovery. Generative AI is becoming an integral part of business operations,        │
# │  acting as a daily tool and copilot.                                                                            │
# │  *   **Overall Trend:** From hype to essential business tool.                                                   │
# │  I need to continue to gather information on other significant AI trends to ensure a comprehensive report.      │
# │  Based on the initial search, these include:                                                                    │
# │  1.  **Multimodal AI:** This was mentioned as a rapid AI trend and a new AI in 2024, allowing systems to        │
# │  combine text, voice, images, and video.                                                                        │
# │  2.  **AI in the workplace/Business Automation:** Mentioned by IBM, Coursera, and CHI Software. This relates    │
# │  to increased AI adoption and business automation benefiting from AI.                                           │
# │  3.  **Ethical AI and Regulation:** Highlighted by AI Magazine and Stanford HAI.                                │
# │  4.  **Sustainability:** Mentioned as a top AI topic for 2024.                                                  │
# │  5.  **Small Language Models (SLMs):** Mentioned by Khoros as a rapid AI trend in 2025.                         │
# │  I will now focus on Multimodal AI to understand its advancements, emerging technologies, and key players.      │
# │                                                                                                                 │
# │  Using Tool: Search the internet with Serper                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Output ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  {'searchParameters': {'q': 'Multimodal AI advancements and key players 2024', 'type': 'search', 'num': 10,     │
# │  'engine': 'google'}, 'organic': [{'title': 'Top 10 Multimodal Models - Encord', 'link':                        │
# │  'https://encord.com/blog/top-multimodal-models/', 'snippet': 'Multimodal models are AI deep-learning models    │
# │  that simultaneously process different modalities, such as text, video, audio, and image, to generate           │
# │  outputs.', 'position': 1}, {'title': 'Top 10 Multimodal AI Models of 2024 - Zilliz Learn', 'link':             │
# │  'https://zilliz.com/learn/top-10-best-multimodal-ai-models-you-should-know', 'snippet': 'Multimodal models     │
# │  are AI systems that simultaneously process and integrate multiple data types.', 'position': 2}, {'title':      │
# │  "AI's Biggest Moments Of 2024: What We Learned This Year - Forbes", 'link':                                    │
# │  'https://www.forbes.com/sites/committeeof200/2024/12/12/ais-biggest-moments-of-2024-what-we-learned-this-year  │
# │  /', 'snippet': 'Multimodal AI Makes Strides, Empowering Consumers with Creative Tools. In early 2024, tech     │
# │  companies began showcasing their advancements in ...', 'position': 3}, {'title': 'What Is Multimodal AI? Top   │
# │  5 Models for Businesses in 2024 | DaveAI', 'link':                                                             │
# │  'https://www.iamdave.ai/blog/what-is-multimodal-ai-top-5-multimodal-ai-models-for-businesses-in-2024/',        │
# │  'snippet': 'Top 5 Multimodal AI Models In 2024 · A. Google Gemini · B. GPT-4V · C. Inworld AI · D. Meta        │
# │  ImageBind · E. Runway Gen-2.', 'position': 4}, {'title': 'What is multimodal AI? - McKinsey', 'link':          │
# │  'https://www.mckinsey.com/featured-insights/mckinsey-explainers/what-is-multimodal-ai', 'snippet':             │
# │  'Multimodal AI is a type of artificial intelligence that can understand and process different types of         │
# │  information, such as text, images, audio, and video, all ...', 'position': 5}, {'title': 'Top 10: AI Trends    │
# │  in 2024 - AI Magazine', 'link': 'https://aimagazine.com/top10/top-10-ai-trends-in-2024', 'snippet': 'The       │
# │  biggest AI trends of 2024 included accessibility, ethics, sustainability and regulation, with companies ...    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────── 🔧 Agent Tool Execution ────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Market Researcher                                                                                       │
# │                                                                                                                 │
# │  Thought: Thought: I have gathered significant information on Generative AI and Multimodal AI.                  │
# │  For Generative AI:                                                                                             │
# │  *   **Investment:** $33.9 billion in 2024, up 18.7% from 2023.                                                 │
# │  *   **Key Players:** OpenAI, Google DeepMind, IBM Watson, Microsoft Azure AI, NVIDIA AI, Amazon Web Services,  │
# │  Adobe Sensei, Anthropic AI. SAP is also partnering with tech giants. Deloitte is implementing many projects.   │
# │  *   **Advancements:** Google's Imagen, Veo, MusicFX. AI-generated art and drug discovery. Integration into     │
# │  business operations as a daily tool.                                                                           │
# │  *   **Trend:** Moving from hype to essential business tool.                                                    │
# │  For Multimodal AI:                                                                                             │
# │  *   **Definition:** AI deep-learning models that simultaneously process different modalities like text,        │
# │  video, audio, and image to generate outputs.                                                                   │
# │  *   **Market Size:** Exceeded $1.6 billion in 2024, projected to grow at a CAGR of over 32.7% from 2025 to     │
# │  2034.                                                                                                          │
# │  *   **Key Models/Players:** Google Gemini, GPT-4V, Inworld AI, Meta ImageBind, Runway Gen-2. Upcoming models   │
# │  include GPT-5, Claude 3, Google Gemini 2.0, Gemma 3, Kosmos-2, LLaMA 3.2.                                      │
# │  *   **Applications:** Healthcare, autonomous vehicles. Empowering consumers with creative tools.               │
# │  *   **Trend:** A new frontier in AI, offering bigger opportunities but also more complex challenges.           │
# │  I still need to research other crucial trends to make the report comprehensive:                                │
# │  1.  **AI in the workplace/Business Automation**                                                                │
# │  2.  **Ethical AI and Regulation**                                                                              │
# │  3.  **Sustainability in AI**                                                                                   │
# │  4.  **Small Language Models (SLMs)**                                                                           │
# │  I will now search for "AI in the workplace and business automation trends 2024".                               │
# │                                                                                                                 │
# │  Using Tool: Search the internet with Serper                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────── 🔧 Agent Tool Execution ────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Market Researcher                                                                                       │
# │                                                                                                                 │
# │  Thought: Thought: I have gathered information on AI in the workplace and business automation.                  │
# │  Key findings include:                                                                                          │
# │  *   **Adoption:** 75% of surveyed workers were using AI in the workplace in 2024 (AIPRM). Almost all           │
# │  companies are investing in AI (McKinsey).                                                                      │
# │  *   **Benefits:** Increased efficiency, reduced operational costs, enhanced decision-making (Rapid             │
# │  Innovation). Streamlining job processes, summarizing information effectively (National University).            │
# │  Automating routine tasks, improving productivity, fostering new skills and creative workflows, supporting      │
# │  employee well-being (IBM).                                                                                     │
# │  *   **Impact on Jobs:** AI is taking over jobs like data entry, scheduling, and customer service (Forbes).     │
# │  However, it also creates new roles and job opportunities (Aspen University). AI will redefine productivity,    │
# │  emphasizing human-machine collaboration (EY).                                                                  │
# │  *   **Maturity:** Only 1% of companies believe they are at AI maturity (McKinsey), indicating significant      │
# │  room for growth and further integration.                                                                       │
# │  Now I need to research **Ethical AI and Regulation** and **Sustainability in AI**. I will combine these into   │
# │  one search since they are often discussed together.                                                            │
# │                                                                                                                 │
# │  Using Tool: Search the internet with Serper                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Output ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  {'searchParameters': {'q': 'Ethical AI, AI regulation, and AI sustainability trends 2024', 'type': 'search',   │
# │  'num': 10, 'engine': 'google'}, 'organic': [{'title': 'AI governance trends: How regulation, collaboration,    │
# │  and skills ...', 'link': 'https://www.weforum.org/stories/2024/09/ai-governance-trends-to-watch/', 'snippet':  │
# │  'In 2024, we saw an increased focus on AI safety with the launch of new AI safety institutes and the           │
# │  expansion of efforts driven by institutes ...', 'position': 1}, {'title': "What's Next for Responsible AI in   │
# │  2024? | Institute for Experiential AI", 'link':                                                                │
# │  'https://ai.northeastern.edu/news/whats-next-for-responsible-ai-in-2024', 'snippet': 'Responsible AI demands   │
# │  a strategy that spans across teams and verticals, with new expertise, creative design workflows, and           │
# │  compliance with emerging ...', 'position': 2}, {'title': 'A review of green artificial intelligence: Towards   │
# │  a more sustainable ...', 'link': 'https://www.sciencedirect.com/science/article/pii/S0925231224008671',        │
# │  'snippet': 'This paper discusses green AI as a pivotal approach to enhancing the environmental sustainability  │
# │  of AI systems.', 'position': 3}, {'title': 'Artificial Intelligence and Compliance: Preparing for the Future   │
# │  of AI ...', 'link':                                                                                            │
# │  'https://www.navex.com/en-us/blog/article/artificial-intelligence-and-compliance-preparing-for-the-future-of-  │
# │  ai-governance-risk-and-compliance/', 'snippet': "AI regulation is set to expand significantly globally,        │
# │  focusing on data privacy, ethical AI usage, and risk mitigation. The European Union's ...", 'position': 4},    │
# │  {'title': 'Summary Artificial Intelligence 2024 Legislation', 'link':                                          │
# │  'https://www.ncsl.org/technology-and-communication/artificial-intelligence-2024-legislation', 'snippet':       │
# │  'Requires the Department of Technology to develop and adopt regulations to create an automated decision        │
# │  system standard. Government Use; Provenance; Responsible ...', 'position': 5}, {'title': 'AI principles -      │
# │  OECD', 'link': 'https://www.oecd.org/en/topi...                                                                │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────── 🔧 Agent Tool Execution ────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Market Researcher                                                                                       │
# │                                                                                                                 │
# │  Thought: Thought: I have successfully gathered information on Ethical AI, AI Regulation, and AI                │
# │  Sustainability.                                                                                                │
# │  Key findings include:                                                                                          │
# │  *   **Ethical AI:** Increased focus on AI safety with new AI safety institutes (WEF). Demands a strategy       │
# │  across teams, new expertise, creative design workflows, and compliance (Northeastern). Concerns include        │
# │  misuse of personal data, false representations, and intellectual property abuse (American Century).            │
# │  *   **AI Regulation:** Set to expand significantly globally (Navex). Examples include the European Union's AI  │
# │  Act and states developing regulations for automated decision systems (NCSL). OECD AI principles, adopted in    │
# │  2019 and updated in 2024, provide guidance. Governments are focusing on governance, provenance, and            │
# │  responsible use.                                                                                               │
# │  *   **AI Sustainability:** Green AI is a pivotal approach to enhancing environmental sustainability of AI      │
# │  systems (ScienceDirect). AI's high demand for electricity and water is a concern (American Century).           │
# │  Opportunities exist to use AI to measure emissions, forecast extreme weather, and reduce waste (EY).           │
# │  The only remaining major trend identified from the initial search is **Small Language Models (SLMs)**. I will  │
# │  conduct a specific search for this now.                                                                        │
# │                                                                                                                 │
# │  Using Tool: Search the internet with Serper                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Output ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  {'searchParameters': {'q': 'Small Language Models (SLMs) advancements and key players 2024', 'type':           │
# │  'search', 'num': 10, 'engine': 'google'}, 'organic': [{'title': 'Small Language Models (SMLs) Company          │
# │  Evaluation Report 2025', 'link':                                                                               │
# │  'https://finance.yahoo.com/news/small-language-models-smls-company-090100930.html', 'snippet': 'Key players    │
# │  in the Small Language Model (SLM) market are actively investing in research and development, forming           │
# │  strategic partnerships, and ...', 'position': 1}, {'title': 'What are Small Language Models (SLM)? - IBM',     │
# │  'link': 'https://www.ibm.com/think/topics/small-language-models', 'snippet': 'Small language models (SLMs)     │
# │  are artificial intelligence (AI) models capable of processing, understanding and generating natural language   │
# │  content.', 'position': 2}, {'title': 'Small Language Models Market Size, Forecasts Report 2034', 'link':       │
# │  'https://www.gminsights.com/industry-analysis/small-language-models-market', 'snippet': 'The global small      │
# │  language models market was valued at USD 6.5 billion in 2024 and is estimated to register a CAGR of 25.7%      │
# │  between 2025 and 2034.', 'position': 3}, {'title': '[PDF] Small Language Models are the Future of Agentic AI   │
# │  - arXiv', 'link': 'https://arxiv.org/pdf/2506.02153', 'snippet': 'Here we lay out the position that small      │
# │  language models (SLMs) are sufficiently powerful, inherently more suitable, and necessarily more economical    │
# │  for many ...', 'position': 4}, {'title': 'The Rise of Small Language Models (SLMs) in AI Development',         │
# │  'link': 'https://wizr.ai/blog/rise-of-small-language-models-slms-in-ai-development/', 'snippet': 'The rise of  │
# │  Small Language Models (SLMs) in AI development is reshaping how businesses use AI – faster, cheaper, and more  │
# │  focused. From mobile ...', 'position': 5}, {'title': 'AI: What are SLMs and are they good for businesses?',    │
# │  'link': 'https://www.weforum.org/stories/2025/01/ai-small-language-models/', 'snippet': 'In December 2024,     │
# │  Microsoft released the latest SLM in its Phi family...                                                         │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Market Researcher                                                                                       │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  **Report: Latest Trends in the AI Industry (2024)**                                                            │
# │                                                                                                                 │
# │  **Executive Summary:**                                                                                         │
# │  The AI industry in 2024 has witnessed unprecedented growth and transformative advancements, moving beyond      │
# │  theoretical concepts to practical, impactful applications across various sectors. Key trends include the       │
# │  maturation and widespread adoption of Generative AI, the emergence of highly sophisticated Multimodal AI,      │
# │  increasing integration of AI into the workplace for automation and augmented human capabilities, a growing     │
# │  focus on ethical considerations and robust regulatory frameworks, and a critical look at AI's environmental    │
# │  sustainability. Furthermore, Small Language Models (SLMs) are gaining traction as efficient and specialized    │
# │  alternatives to their larger counterparts. This report details these significant advancements, emerging        │
# │  technologies, and key players shaping the future of artificial intelligence.                                   │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  **1. Generative AI: From Hype to Essential Business Tool**                                                     │
# │                                                                                                                 │
# │  Generative AI (GenAI) has transitioned from a buzzword to a fundamental technology driving innovation and      │
# │  efficiency across industries.                                                                                  │
# │                                                                                                                 │
# │  *   **Significant Advancements:**                                                                              │
# │      *   **Content Creation:** Enhanced capabilities in generating high-quality text, images, video, and        │
# │  audio. Google's Imagen, Veo, and MusicFX have seen significant updates, enabling more creative and realistic   │
# │  outputs from text prompts.                                                                                     │
# │      *   **Drug Discovery & Scientific Research:** AI is now being used to discover novel drug molecules,       │
# │  significantly accelerating research and development in healthcare. AI-generated art has also seen commercial   │
# │  success, with paintings selling for over $1 million.                                                           │
# │      *   **Enterprise Integration:** GenAI is becoming an integral part of business operations, serving as a    │
# │  daily tool and "copilot" for skilled workers, automating tasks, and assisting in complex problem-solving.      │
# │      *   **Customization:** The trend towards customizable generative AI models allows businesses to fine-tune  │
# │  AI for specific tasks and domain knowledge, improving relevance and accuracy.                                  │
# │                                                                                                                 │
# │  *   **Key Players:**                                                                                           │
# │      *   **Foundational Model Developers:** OpenAI, Google DeepMind, IBM Watson, Microsoft Azure AI, NVIDIA     │
# │  AI, Amazon Web Services, Adobe Sensei, Anthropic AI.                                                           │
# │      *   **Enablers & Implementers:** SAP is actively integrating generative AI through partnerships with tech  │
# │  giants like Google, Meta, Microsoft, and NVIDIA. Consulting firms like Deloitte have been pivotal in driving   │
# │  large-scale AI transformations, having delivered over 700 generative AI projects by June 2024.                 │
# │                                                                                                                 │
# │  *   **Investment & Market Impact:**                                                                            │
# │      *   Generative AI attracted a staggering $33.9 billion globally in private investment in 2024, marking an  │
# │  18.7% increase from 2023, according to Stanford HAI. This significant investment underscores the market's      │
# │  confidence in its transformative potential.                                                                    │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  **2. Multimodal AI: Expanding Perception and Interaction**                                                     │
# │                                                                                                                 │
# │  Multimodal AI represents a significant leap forward, allowing AI systems to understand and process             │
# │  information from various data types simultaneously, mirroring human perception more closely.                   │
# │                                                                                                                 │
# │  *   **Emerging Technologies & Advancements:**                                                                  │
# │      *   **Integrated Understanding:** These AI deep-learning models can simultaneously process and integrate   │
# │  text, images, video, and audio to generate more comprehensive and intuitive outputs. This allows for more      │
# │  nuanced interpretations and richer interactions.                                                               │
# │      *   **Enhanced User Experience:** Multimodal AI empowers consumers with more intuitive creative tools and  │
# │  more comprehensive user interactions by combining diverse inputs.                                              │
# │      *   **Agentic AI:** The development of multimodal AI agents that can reason and interact across different  │
# │  modalities is a new frontier, moving from reactive to proactive AI systems.                                    │
# │                                                                                                                 │
# │  *   **Key Models & Players:**                                                                                  │
# │      *   **Leading Models:** Google Gemini, GPT-4V, Inworld AI, Meta ImageBind, and Runway Gen-2 are prominent  │
# │  multimodal models.                                                                                             │
# │      *   **Upcoming Developments:** Anticipated advancements include GPT-5, Claude 3, Google Gemini 2.0, Gemma  │
# │  3, Kosmos-2, and LLaMA 3.2, which promise even more sophisticated multimodal capabilities.                     │
# │                                                                                                                 │
# │  *   **Market Growth & Applications:**                                                                          │
# │      *   The global multimodal AI market was valued at over $1.6 billion in 2024 and is projected to grow at a  │
# │  Compound Annual Growth Rate (CAGR) of over 32.7% from 2025 to 2034.                                            │
# │      *   **Diverse Applications:** Key application areas span healthcare (e.g., integrated patient              │
# │  diagnostics), autonomous vehicles (e.g., understanding road signs, voice commands, and real-time video), and   │
# │  creative industries.                                                                                           │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  **3. AI in the Workplace and Business Automation**                                                             │
# │                                                                                                                 │
# │  AI's integration into the workplace is rapidly increasing, transforming business operations, enhancing         │
# │  productivity, and redefining job roles.                                                                        │
# │                                                                                                                 │
# │  *   **Increased Adoption & Impact:**                                                                           │
# │      *   **Widespread Usage:** Approximately 75% of surveyed workers were using AI in the workplace in 2024,    │
# │  indicating broad adoption. Almost all companies are investing in AI, although only 1% believe they have        │
# │  reached full AI maturity.                                                                                      │
# │      *   **Efficiency & Cost Reduction:** AI implementation leads to increased operational efficiency, reduced  │
# │  costs, and enhanced decision-making by automating routine, repetitive tasks.                                   │
# │      *   **Augmented Workforce:** AI streamlines job processes, effectively summarizes information, and         │
# │  supports employee well-being by freeing up time for more creative and strategic work. It fosters the           │
# │  development of new skills and encourages more creative workflows.                                              │
# │                                                                                                                 │
# │  *   **Transformation of Jobs:**                                                                                │
# │      *   **Task Automation:** AI is increasingly taking over jobs involving data entry, scheduling, and         │
# │  customer service through tools like chatbots and Robotic Process Automation (RPA).                             │
# │      *   **Job Creation & Collaboration:** Despite concerns about job displacement, AI also creates new roles   │
# │  and opportunities. The future of work emphasizes human-machine collaboration, where AI augments human          │
# │  capabilities rather than fully replacing them. AI will redefine productivity by enabling new knowledge         │
# │  creation and experiences.                                                                                      │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  **4. Ethical AI and Regulation: Building Trust and Ensuring Responsibility**                                   │
# │                                                                                                                 │
# │  As AI becomes more pervasive, the imperative for ethical development and robust regulation has taken center    │
# │  stage, focusing on safety, fairness, and accountability.                                                       │
# │                                                                                                                 │
# │  *   **Ethical Considerations & AI Safety:**                                                                    │
# │      *   **Increased Focus on Safety:** 2024 saw an increased global focus on AI safety, with the               │
# │  establishment of new AI safety institutes and expanded efforts by existing research bodies.                    │
# │      *   **Concerns:** Key ethical concerns include the potential misuse of personal data, the creation of      │
# │  false representations (deepfakes), and the abuse of intellectual property rights. Addressing bias in AI        │
# │  systems also remains a critical challenge.                                                                     │
# │      *   **Responsible AI Strategies:** Implementing responsible AI requires a cross-functional strategy        │
# │  involving new expertise, creative design workflows, and continuous compliance with emerging standards.         │
# │                                                                                                                 │
# │  *   **Regulatory Landscape:**                                                                                  │
# │      *   **Global Expansion:** AI regulation is set to expand significantly worldwide.                          │
# │      *   **Key Legislation:** The European Union's AI Act is a landmark example, aiming to establish a          │
# │  comprehensive legal framework for AI. Many countries and states, such as those covered by the NCSL, are        │
# │  developing their own regulations for automated decision systems, focusing on government use, data provenance,  │
# │  and responsible AI practices.                                                                                  │
# │      *   **International Standards:** The OECD AI Principles, initially adopted in 2019 and updated in 2024,    │
# │  provide practical and flexible guidance based on five values-based principles and five recommendations for     │
# │  the responsible stewardship of trustworthy AI.                                                                 │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  **5. AI Sustainability: Addressing the Environmental Footprint**                                               │
# │                                                                                                                 │
# │  The environmental impact of AI, particularly its energy and resource demands, has become a critical area of    │
# │  focus, leading to the rise of "Green AI."                                                                      │
# │                                                                                                                 │
# │  *   **Challenges:**                                                                                            │
# │      *   **High Resource Consumption:** AI's intensive computational requirements lead to a high demand for     │
# │  electricity and water, contributing to carbon emissions. This "environmental footprint" is a significant       │
# │  concern for the long-term sustainability of AI development and deployment.                                     │
# │                                                                                                                 │
# │  *   **Opportunities & Solutions (Green AI):**                                                                  │
# │      *   **Sustainable AI Systems:** Green AI is emerging as a pivotal approach to enhance the environmental    │
# │  sustainability of AI systems, focusing on energy-efficient algorithms, hardware, and data centers.             │
# │      *   **AI for Sustainability:** AI itself offers powerful tools to address climate change and promote       │
# │  sustainability. It can be applied to measure emissions, forecast extreme weather events, optimize energy       │
# │  grids, and reduce waste in various sectors.                                                                    │
# │      *   **Policy & Practices:** Organizations are exploring current legislation and developing strategies to   │
# │  minimize their AI's environmental impact, balancing innovation with ecological responsibility.                 │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  **6. Small Language Models (SLMs): The Rise of Specialized Efficiency**                                        │
# │                                                                                                                 │
# │  While Large Language Models (LLMs) continue to dominate headlines, Small Language Models (SLMs) are rapidly    │
# │  gaining prominence as efficient, cost-effective, and specialized alternatives.                                 │
# │                                                                                                                 │
# │  *   **Advancements & Characteristics:**                                                                        │
# │      *   **Efficiency & Cost-Effectiveness:** SLMs have fewer parameters than LLMs, making them faster,         │
# │  cheaper to train and deploy, and requiring fewer computational resources. This makes them more accessible and  │
# │  adaptable for many organizations.                                                                              │
# │      *   **Specialized Capabilities:** SLMs are often fine-tuned on smaller, specific datasets for particular   │
# │  use cases, enabling them to outperform larger models on targeted tasks, especially in niche domains or on      │
# │  edge devices.                                                                                                  │
# │      *   **Democratization of AI:** SLMs democratize AI by making advanced natural language processing          │
# │  capabilities more accessible to businesses with limited resources or specific needs.                           │
# │                                                                                                                 │
# │  *   **Key Players & Models:**                                                                                  │
# │      *   **Industry Leaders:** Key players in the SLM market, including Microsoft (with its Phi family, e.g.,   │
# │  Phi-4), IBM, Infosys, Mistral AI, and OpenAI, are actively investing in research and development.              │
# │      *   **Prominent SLMs:** Notable SLMs include Microsoft's Phi models, Llama 3.1 8B, Gemma2, Qwen 2 (0.5b,   │
# │  1b, 7b), Mistral Nemo, and Cerebras-GPT.                                                                       │
# │                                                                                                                 │
# │  *   **Market Growth & Impact:**                                                                                │
# │      *   The global SLM market was valued at USD 6.5 billion in 2024 and is estimated to register a CAGR of     │
# │  25.7% between 2025 and 2034 (or 15.6% from 2024 to 2034, depending on the source), indicating robust growth.   │
# │      *   **Enterprise Adoption:** SLMs are emerging as strategic alternatives to LLMs, particularly for         │
# │  enterprises looking to scale AI solutions more efficiently and for specific agentic AI tasks. They are         │
# │  expected to advance digital transformation across various industries.                                          │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  **Conclusion:**                                                                                                │
# │                                                                                                                 │
# │  The AI industry in 2024 is characterized by rapid innovation and a pragmatic shift towards real-world          │
# │  applications. Generative AI and Multimodal AI are pushing the boundaries of what machines can create and       │
# │  understand, while their integration into the workplace is fundamentally changing how businesses operate and    │
# │  how humans interact with technology. Concurrently, a crucial focus on ethical development, robust regulation,  │
# │  and environmental sustainability is shaping a more responsible AI future. The rise of Small Language Models    │
# │  highlights a growing emphasis on efficiency and specialization, ensuring AI becomes even more pervasive and    │
# │  tailored to diverse needs. These trends collectively underscore a dynamic and evolving landscape where AI is   │
# │  not just a technological advancement but a societal and economic force.                                        │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Content Writer                                                                                          │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  # AI Unpacked: The Game-Changing Trends Shaping Our Future in 2024                                             │
# │                                                                                                                 │
# │  Remember when AI felt like something out of a sci-fi movie? Well, buckle up, because 2024 has seen Artificial  │
# │  Intelligence leap out of the silver screen and into our everyday lives, transforming industries, jobs, and     │
# │  even how we interact with technology. It's not just about robots anymore; it's about smart systems that are    │
# │  reshaping our world in fascinating ways. Let's dive into the most exciting AI trends of the year!              │
# │                                                                                                                 │
# │  ### Generative AI: From Buzzword to Your New Co-Pilot                                                          │
# │                                                                                                                 │
# │  Generative AI (GenAI), the technology behind creating stunning images, compelling text, and even original      │
# │  music from simple prompts, has truly come of age. No longer just a futuristic concept, GenAI is now an         │
# │  essential business tool. Imagine AI helping scientists discover new drug molecules, speeding up medical        │
# │  research, or assisting marketing teams in crafting perfect campaigns. Companies are integrating GenAI as a     │
# │  "copilot" for skilled workers, automating mundane tasks, and freeing up human creativity for more complex      │
# │  problem-solving. It's like having a brilliant assistant available 24/7! With a staggering $33.9 billion        │
# │  invested globally this year, it's clear the market believes in its transformative power.                       │
# │                                                                                                                 │
# │  ### Multimodal AI: AI That Sees, Hears, and Understands                                                        │
# │                                                                                                                 │
# │  Prepare for AI that understands the world much like we do. Multimodal AI is a groundbreaking advancement       │
# │  allowing AI systems to process and integrate different types of information – like text, images, video, and    │
# │  audio – simultaneously. Think of Google Gemini or GPT-4V, which can analyze a picture, understand its          │
# │  context, and answer questions about it, all at once. This capability leads to richer, more intuitive           │
# │  interactions with technology and opens doors for incredible applications in healthcare, where AI can           │
# │  integrate patient data with imaging, or in autonomous vehicles, understanding both visual cues and spoken      │
# │  commands. It’s AI that’s truly getting the full picture.                                                       │
# │                                                                                                                 │
# │  ### AI in the Workplace: Redefining Productivity and Roles                                                     │
# │                                                                                                                 │
# │  AI isn't just a tool; it's a colleague. Roughly 75% of workers reported using AI in their jobs this year,      │
# │  indicating its widespread adoption. AI is taking over repetitive tasks like data entry and scheduling,         │
# │  allowing human employees to focus on strategic, creative, and fulfilling work. This isn't about replacing      │
# │  humans but augmenting our capabilities. AI streamlines processes, enhances decision-making, and even supports  │
# │  employee well-being by giving us more time for what truly matters. The future workplace will be a              │
# │  collaboration between humans and intelligent machines, creating new opportunities and efficiencies.            │
# │                                                                                                                 │
# │  ### The Ethical Imperative: Building Trust in AI                                                               │
# │                                                                                                                 │
# │  As AI becomes more powerful, the conversation around ethical development and robust regulation has taken       │
# │  center stage. We’re seeing a global push for "Responsible AI," focusing on safety, fairness, and               │
# │  accountability. Concerns about data misuse, deepfakes, and intellectual property are driving new legislation,  │
# │  such as the EU's landmark AI Act. This focus ensures that as AI evolves, it does so in a way that benefits     │
# │  society, respects privacy, and operates without bias. Building trust in AI is paramount for its long-term      │
# │  success.                                                                                                       │
# │                                                                                                                 │
# │  ### Green AI: A Sustainable Future                                                                             │
# │                                                                                                                 │
# │  The environmental footprint of AI is a growing concern. Training and running advanced AI models consume        │
# │  significant amounts of energy and water. This has led to the rise of "Green AI," a movement focused on         │
# │  developing energy-efficient algorithms, hardware, and data centers. But it’s a two-way street: AI itself is    │
# │  also becoming a powerful tool *for* sustainability, helping us measure emissions, forecast extreme weather,    │
# │  and optimize energy grids. It’s about ensuring AI innovation goes hand-in-hand with ecological                 │
# │  responsibility.                                                                                                │
# │                                                                                                                 │
# │  ### The Rise of Small Language Models (SLMs): Efficiency is Key                                                │
# │                                                                                                                 │
# │  While Large Language Models (LLMs) grab headlines, Small Language Models (SLMs) like Microsoft's Phi models    │
# │  are making a significant impact. These specialized, efficient models have fewer parameters, making them        │
# │  faster, cheaper to train, and more accessible for businesses with specific needs. SLMs can often outperform    │
# │  larger models on targeted tasks, especially in niche domains or on smaller devices. They're democratizing AI,  │
# │  allowing more organizations to harness its power without massive computational resources.                      │
# │                                                                                                                 │
# │  ### The AI Horizon                                                                                             │
# │                                                                                                                 │
# │  The AI landscape in 2024 is defined by breathtaking innovation and a practical pivot towards real-world        │
# │  impact. From the creative power of Generative AI and the comprehensive understanding of Multimodal AI to the   │
# │  ethical guardrails and sustainable practices shaping its future, AI is not just a technological advancement –  │
# │  it's a societal and economic force. Get ready, because the future, powered by intelligent machines working     │
# │  alongside us, is here.                                                                                         │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯

# %%
# Define the filename
output_filename = "blog_post.md"

# Open the file in write mode ('w') and save the content
with open(output_filename, 'w', encoding='utf-8') as file:
    file.write(result.raw)

print(f"\n Blog post successfully saved to {output_filename}")
# Out:
#  Blog post successfully saved to blog_post.md
